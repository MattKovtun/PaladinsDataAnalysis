# %%
import os

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# %%
folder = '../data/daily/ranked_siege/'

# %%
files = os.listdir(folder)

# %%
d = []
m = []

# %%
for f in files:
    p = folder + f
    with open(p) as ff:
        m.append(int(ff.readline()))
        d.append(f)

# %%
plt.figure(figsize=(20,8))
plt.plot(matches)

# %%
plt.figure(figsize=(20,8))
plt.plot(m)
