# %%
import pandas as pd
import json
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
match_summary = '../data/processed/match_summary/v1.csv'

# %%
df = pd.read_csv(match_summary)

# %%
df.head()
# Out:
#      matchid    hero  winner  healing  damage_taken  damage_done  tier
# 0  907919212  Viktor    True        0         23176        71829    18
# 1  907919212    Zhin    True        0         27645        61267    18
# 2  907919212   Inara    True        0         65480        26890    11
# 3  907919212   Furia    True    77648         13725        28692    17
# 4  907919212   Makoa    True        0         58257        46479    20

# %%
x = df[df['hero'] == 'Inara'].groupby('tier')['damage_taken'].mean()

# %%
plt.scatter(x=x.keys(), y=x)

# %%
df[df['hero'] == 'Inara'].plot.scatter(figsize=(16,8),x='tier', y='damage_done')

# %%
df[df['hero'] == 'Inara'].plot.scatter(figsize=(16,8),x='damage_taken', y='damage_done')

# %%
val = [10, 20]
dd_val = ['Viktor', 'Makoa']

data_selection = df[(df['tier'] >= val[0])
                & (df['tier'] <= val[1])]

data_selection = data_selection[data_selection['hero'].isin(dd_val)]

dd = data_selection.groupby(['tier', 'hero'])['damage_taken'].mean()

print(dd)
# Out:
# tier  hero
# 10    Makoa      83154.550000
#       Viktor     40397.916667
# 11    Makoa     105072.090909
#       Viktor     44744.339623
# 12    Makoa      97811.431818
#       Viktor     40225.655172
# 13    Makoa      89522.700000
#       Viktor     42410.600000
# 14    Makoa      94744.153846
#       Viktor     39746.108696
# 15    Makoa      89272.931818
#       Viktor     38734.885714
# 16    Makoa      87408.721311
#       Viktor     39326.586207
# 17    Makoa      99301.840000
#       Viktor     41826.714286
# 18    Makoa     102801.480769
#       Viktor     38319.135135
# 19    Makoa     103409.208333
#       Viktor     43424.230769
# 20    Makoa      99544.538462
#       Viktor     42325.500000
# Name: damage_taken, dtype: float64

# %%
dd.loc[(11, 'Makoa')]
# Out:
# 105072.09090909091

# %%
dd.keys()['tier']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-896135912469> in <module>
# ----> 1 dd.keys()['tier']
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/multi.py in __getitem__(self, key)
#    1765             retval = []
#    1766             for lev, level_codes in zip(self.levels, self.codes):
# -> 1767                 if level_codes[key] == -1:
#    1768                     retval.append(np.nan)
#    1769                 else:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
