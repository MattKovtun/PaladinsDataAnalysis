# %%
import pandas as pd
import json
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
match_summary = '../data/processed/match_summary/v1.csv'

# %%
df = pd.read_csv(match_summary)

# %%
df.head()
# Out:
#      matchid    hero  winner  healing  damage_taken  damage_done
# 0  907919212  Viktor    True        0         23176        71829
# 1  907919212    Zhin    True        0         27645        61267
# 2  907919212   Inara    True        0         65480        26890
# 3  907919212   Furia    True    77648         13725        28692
# 4  907919212   Makoa    True        0         58257        46479

# %%
df[df['hero'] == 'Inara'].plot.scatter(figsize=(16,8),x='damage_taken', y='damage_done')
